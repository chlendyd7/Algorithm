# %% [markdown]
# # [Kaggle] Bike Sharing Demand예측 AI모델 개발
#
# ## [target이 복수개인 경우]
# - count, registered, casual을 모두 예측해야 하는 ' MultiOutput'이라면...
# - MultiOutputRegressor를 사용하여 학습 및 예측!
#
# ## 개요
# - 시간대별 자전거 대여량 예측

# %% [markdown]
# ## 분석 배경
# - 워싱턴 D.C 소재의 자전거 대여 스타트업인 Capital Bikeshare의 데이터를 활용
# - 시간대별 자전거 대여량 예측함
# - https://softeer.ai/practice?type=DA&page=0

# %% [markdown]
# ## 평가 지표
# - RMSLE : Root Mean Scaled Logarithmic Error
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## 데이터 셋 정보

# %% [markdown]
# ### [Data Files]
# - (2011, 2012) 2년간 데이터
# - train.csv: 학습용 데이터 (Features, Target) - 10,886건
#     - 매달 1일~19일까지의 데이터
# - test.csv:  예측용 데이터 (Features) - 6,439건
#     - 매달 20일~말일까지의 데이터

# %% [markdown]
# ### [Feature]
# - datetime: 자전거 대여가 일어난 년-월-일-시-분-초
# - season: 계절
#     – 1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday: 공휴일이면 1, 아니면 0
# - workingday: 근무일이면 1, 아니면 0
# - weather (날씨)
#     - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp: 온도
# - atemp: 체감온도
# - humidity: 습도
# - windspeed: 풍속

# %% [markdown]
# ### [Target] -3개
# - count: (시간대별) 자건거 대여량
# - casual: (시간대별) 비회원의 자전거 대여량
# - registered: (시간대별) 회원의 자전거 대여량

# %% [markdown]
# ## 분석 단계
# - **[step1] 라이브러리 및 데이터 불러오기**
#  - (1) 라이브러리 불러오기
#  - (2) 데이터 불러오기
#  - (3) 데이터 확인
#  - (4) 데이터 타입 변환 (필요시)
# - **[step2] 탐색적 데이터 분석 (EDA)**
#  - (1) 기술적 통계분석
#  - (2) 변수별 분포 시각화
# - **[step3] 데이터 전처리**
#  - (1) 중복값 처리 **(Train셋만)**
#  - (2) 불필요한 Feature 삭제 (ID 등)
#  - (3) 결측치 처리
#  - (4) 아웃라이어 제거 **(Train셋만 & 양적변수만)**
#  - (5) Feature, Target 설정
#  - (6) 원핫 인코딩 **(feature-질적변수만)**
#  - (7) 스케일링 **(feature-양적변수만)**
# - **[step4] 모델 설계**
#  - (1) 훈련 및 검증 데이터 분할
#  - (2) 평가지표 확인
#  - (3) 알고리즘별 학습, 예측, 평가
#  - (4) 하이퍼 파라미터 튜닝
# - **[step5] 모델 선택 및 적용**
#  - (1) test data의 예측값 생성
#  - (2) 예측값 스케일 복구 (로그 변환 등으로 필요시)
# - **[step6] 결과 파일 생성**
#  - (1) 예시 파일 불러오기
#  - (2) test data의 예측 결과 저장
#  - (3) 제출할 csv파일 생성

# %% [markdown]
# ## [Step1] 불러오기
# ### (1) 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# regression models

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.multioutput import MultiOutputRegressor

# %%
from sklearn.model_selection import train_test_split  #학습셋과 검증셋 분리

# %% [markdown]
# ### (2) 데이터 불러오기

# %% [markdown]
# **train data**

# %%
#train set load
train = pd.read_csv('./data/train.csv')
train

# %% [markdown]
# **test data**

# %%
#test set load
test = pd.read_csv('./data/test.csv')
test

# %% [markdown]
# ### (3) 데이터 확인
#  - df.info()

# %%
train.info()

# %% [markdown]
# - Column: 12개, 데이터 건수: 10886
# - 모든 변수의 Non-Null Count 값이 10886 건으로 train data에 결측치가 없음
# - **datetime**의 데이터 타입이 object(문자열)임

# %%
test.info()

# %% [markdown]
# - Column: 12개, 데이터 건수: 6439
# - 모든 변수의 Non-Null Count 값이 6439 건으로 test data에도 결측치가 없음
# - **datetime**의 데이터 타입이 object(문자열)임

# %% [markdown]
# ### (4) 데이터 타입 변환
# - **datetime**을 수치형 데이터 타입인 **datetime64**로 변환
# - 년/월/일/시/분/초 형식의 **datetime64**로 변환해야 추후 분석이 용이함
#     - 예를 들면, **년,월,일,시,분,초** 값을 각각 **분리**할 수 있음

# %% [markdown]
# #### train data

# %%
#datetiem64 형식으로 변환
train['datetime'] = pd.to_datetime(train['datetime'])

# %%
#변환되었는지 확인
train.info()

# %% [markdown]
# - datetime64형 변수의 **dt 속성**을 이용, 년,월,일,시,분,초 값 분리
#     - (ex: dt.year, dt.month)

# %%
# 년,월,일,시,분,초 값 분리
train['year']=train['datetime'].dt.year     # 1. 년도 추출 
train['month']=train['datetime'].dt.month   # 2. 월 추출 
train['day']=train['datetime'].dt.day       # 3. 일 추출 
train['hour']=train['datetime'].dt.hour     # 4. 시 추출 
train['minute']=train['datetime'].dt.minute # 5. 분 추출 
train['second']=train['datetime'].dt.second # 6. 초 추출

# %%
train['dayofweek']=train['datetime'].dt.dayofweek 
#7. 요일 추출  (월요일:0, 일요일:6)

# %%
# 결과 확인
print(train.shape)
train.head()

# %% [markdown]
# #### test data

# %%
#datetiem64 형식으로 변환
test['datetime'] = pd.to_datetime(test['datetime'])

# %%
#변환되었는지 확인
test.info()

# %%
# 년,월,일,시,분,초 값 분리
test['year']=test['datetime'].dt.year # 년도 추출 
test['month']=test['datetime'].dt.month # 월도 추출 
test['day']=test['datetime'].dt.day # 일 추출 
test['hour']=test['datetime'].dt.hour # 시 추출 
test['minute']=test['datetime'].dt.minute # 분 추출 
test['second']=test['datetime'].dt.second # 초 추출 
test['dayofweek']=test['datetime'].dt.dayofweek #요일 추출 , 월요일:0, 일요일:6

# %%
# 결과 확인
print(test.shape)
test.head()

# %% [markdown]
# ## [Step2] 탐색적 데이터 분석 (EDA)

# %% [markdown]
# ### (1) 기술통계분석
# - describe()를 이용한 통계치 확인

# %% [raw]
# # 각 변수들의 기초 통계량을 확인합니다
# train.describe()

# %% [raw]
# test.describe()

# %% [markdown]
# #### [정리] 기술통계분석 결과에서
# - 명목(카테고리) 변수의 경우 평균값 등이 의미가 없음! ==> 오히려 min, max를 통해 카테고리 값이 train과 test셋에 고르게 분포했는지 확인해야 함
#     - season, holiday, weather, year, month, day, hour, minute, second, dayofweek
# - **(중요)** weather의 경우
#     - train셋: 1,2,3,4
#     - test셋:  1,2,3
#     - 이 경우 train셋과 test셋을 각각 one-hot 인코딩하면 **feature수가 달라지게 됨**
# - 분과 초는 단일값 (0)으로 구성, 머신러닝에 도움이 되지 않음
#     - feature로 사용하지 않음, 삭제 예정
# - casual과 registered를 count를 구성하는 값으로 train셋에만 있음
#     - feature로 사용하지 않음, 삭제 예정

# %% [markdown]
# [추가확인-weather]

# %% [raw]
# train["weather"].value_counts()

# %% [raw]
# test["weather"].value_counts()

# %% [markdown]
# ### (2) 변수별 분포 시각화

# %% [markdown]
# #### 1) 변수들간 상관관계를 보여주는 pairplot

# %% [raw]
# # pairplot -변수간 상관관계 확인
#
# # 주요 변수만 추출하여 pairplot
# train_var=train[["season","workingday","weather","temp","humidity","windspeed","count","year","month","day","hour"]]
#
# plt.figure(figsize = (15,15))
# sns.pairplot(train_var)
# plt.show()

# %% [markdown]
# #### [정리] pairplotting을 해 보면,
# - 변수의 형태에 따라서 산점도 양상이 달라짐
#     - (연속형-연속형), (연속형-범주형), (범주형-범주형)
# - 특히 target변수(count)와 feature와의 관계를 유심히 관찰
#     - 'day'변수의 경우 유의미한 관계가 잘 보이지 않음
#     - 확인을 위해 count와 년/월/일/시 변수의 산점도를 확대하여 작성해봄

# %% [raw]
# # count와 년/월/일/시 변수의 산점도
#
# fig,ax=plt.subplots(nrows=2, ncols=2, figsize=(15,8))
#
# sns.scatterplot(x=train["year"],y=train["count"],data=train, ax=ax[0][0])
# sns.scatterplot(x=train["month"],y=train["count"],data=train, ax=ax[0][1])
# sns.scatterplot(x=train["day"],y=train["count"],data=train, ax=ax[1][0])
# sns.scatterplot(x=train["hour"],y=train["count"],data=train, ax=ax[1][1])
#
# plt.show()

# %% [markdown]
# ##### [결론] target에 유의미한 상관성을 보이지 않는 day 변수 제거

# %% [markdown]
# - pairplot의 **대각선**을 따라서는 **개별 변수 분포도**가 제시됨
#     - **연속형 변수: histplot 또는 distplot(histogram )**
#         - feature - temp, atemp, humidity, windspeed, count
#         - target - count
#     - **범주형 변수: countplot**
#         - season, workingday, weather, year, month, hour

# %% [markdown]
# #### 2) 연속형 변수의 분포를 보여주는 distplot

# %% [raw]
# # feature
# fig, axes = plt.subplots(2, 2, figsize=(20,10))
#
# sns.distplot(x = train['temp'], ax=axes[0][0]).set_title('temp')
# sns.distplot(x = train['atemp'], ax=axes[0][1]).set_title('atemp')
# sns.distplot(x = train['humidity'], ax=axes[1][0]).set_title('humidity')
# sns.distplot(x = train['windspeed'], ax=axes[1][1]).set_title('windspeed')
# plt.show()

# %% [markdown]
# #### [Target]
# - target값의 **로그 변환** 필요성 검토

# %% [raw]
# # target값의 원데이터와 로그변환데이터의 분포 비교
# fig, axes = plt.subplots(1, 2, figsize=(15,5))
# sns.histplot(x = train['count'], ax=axes[0])
# sns.histplot(x = np.log1p(train['count']), ax=axes[1])

# %% [raw]
# # target값의 원데이터와 로그변환데이터의 분포 비교
# fig, axes = plt.subplots(1, 2, figsize=(15,5))
# sns.histplot(x = train['casual'], ax=axes[0])
# sns.histplot(x = np.log1p(train['casual']), ax=axes[1])

# %% [raw]
# # target값의 원데이터와 로그변환데이터의 분포 비교
# fig, axes = plt.subplots(1, 2, figsize=(15,5))
# sns.histplot(x = train['registered'], ax=axes[0])
# sns.histplot(x = np.log1p(train['registered']), ax=axes[1])

# %% [markdown]
# - 로그 변환 후, 분포 왜곡도가 완화됨을 알 수 있음

# %% [markdown]
# - [참고] np.log1p(x)함수
#     - log(x+1)을 return함

# %% [markdown]
# ### [참고] 로그 함수의 특징
# - 밀집되어 있는 데이터는 퍼지게, 퍼진 데이터는 밀집되게 하여 원본의 분포왜곡을 완화
#
# <img src="data:image/png;base64,..." width=300 align=left>

# %% [markdown]
# - 0<x<1
#     - 로그 변환후 (-무한대<y<0)의 범위로 분산됨
#     - 즉 제한된 범위의 x는 로그 변환 후 큰 범위로 벌어짐
# - x>1
#     - 로그 변환후 (0<y<특정값)의 범위로 제한됨
#     - 즉 넓은 범위의 x는 로그 변환후 범위가 제한됨

# %% [markdown]
# #### 3) 범주의 변수의 빈도를 보여주는 countplot

# %% [raw]
# # countplot - 범주형 변수의 분포확인
# fig, axes = plt.subplots(2, 4, figsize=(20,10))
#
# sns.countplot(x = train['season'], ax=axes[0][0])
# sns.countplot(x = train['holiday'], ax=axes[0][1])
#
# sns.countplot(x = train['workingday'], ax=axes[0][2])
# sns.countplot(x = train['weather'], ax=axes[0][3])
#
# sns.countplot(x = train['year'], ax=axes[1][0])
# sns.countplot(x = train['month'], ax=axes[1][1])
#
# sns.countplot(x = train['hour'], ax=axes[1][2])
# sns.countplot(x = train['dayofweek'], ax=axes[1][3])
# plt.show()

# %% [markdown]
# ## [step3] 데이터 전처리

# %% [markdown]
# ### (1) 중복값 처리  **(Train셋만)**

# %% [raw]
# # train 셋의 중복값 확인
# train.duplicated()

# %% [raw]
# # train 셋의 중복값의 총갯수 확인
# train.duplicated().sum()

# %% [markdown]
# #### 만약 train data에 중복값이 있다면?
# - df.drop_duplicates()를 이용하여 중복행을 제거

# %% [raw]
# #중복행이 존재하는 train2를 임의로 생성
# temp=train[0:2]
# train2 = train.copy()
# train2=pd.concat([train2, temp])
# train2

# %% [raw]
# train2.duplicated()

# %% [raw]
# #중복행 제거 - 앞쪽을 유지, 뒷쪽을 삭제
# train2.drop_duplicates(keep='first', ignore_index=True)

# %% [raw]
# #중복행 제거 - 뒷쪽을 유지, 앞쪽을 삭제
# train2.drop_duplicates(keep='last', inplace=True)
# train2

# %% [raw]
# train2.duplicated()

# %% [markdown]
# ##### [주의]
# - test 셋의 경우 예측 후 제출 파일과 데이터 건수가 동일해야 함
# - 따라서 중복에 의한 제거처리를 하지 않음

# %% [markdown]
# ### (2) 불필요한 Feature 삭제

# %%
# train set
train.drop(['datetime', 'day', 'minute','second'], axis=1, inplace=True)
train.head()

# test set
test.drop(['datetime', 'day', 'minute','second'], axis=1, inplace=True)
test.head()

print(train.shape)
print(test.shape)

# %% [markdown]
# ### (3) 결측치 처리

# %% [markdown]
# - df.info()를 통해 train과 test 데이터에 결측치가 없음을 이미 확인 했음
# - 추가적으로 아래 방법으로도 확인 가능

# %% [raw]
# train.isnull()

# %% [raw]
# train.isnull().sum()

# %% [raw]
# test.isnull()

# %% [raw]
# test.isnull().sum()

# %% [markdown]
# #### [정리] 만약 결측값이 있다면?
# - df.fillna()를 이용하여 결측값을 채움

# %% [raw]
# # train2를 생성, 일부 field를 결측값으로 변경
# train2 = train.copy()
# train2.loc[0, 'temp'] = np.nan
# train2.loc[1, 'atemp'] = np.nan
# train2.head()

# %% [raw]
# # 결측값을 0으로 채우기
# train3=train2.fillna(0)
# train3.head()

# %% [raw]
# # 결측값을 해당 column 평균값으로 채우기
# train3=train2.fillna(train2.mean())
# train3.head()

# %% [markdown]
# ### (4) 아웃라이어 제거 **(Train셋 & 양적변수만)**

# %% [raw]
# # boxplotting을 통해 outlier 존재여부 확인
# plt.figure(figsize=(3,5))
# sns.boxplot(y="count",data=train)
# plt.show()

# %% [markdown]
# - 아웃라이어 제거 방법
#     - 1) 사분위수 범위(IQR = Q3-Q1)을 계산
#     - 2) **Q1-1.5IQR**과 **Q3+1.5IQR**을 각각 max와 min으로 설정
#     - 3) [min, max]를 벗어나는 데이터는 아웃라이어로 간주하여 제거

# %% [raw]
# # 1) 사분위수 범위(IQR = Q3-Q1)을 계산
# Q1 = train['count'].quantile(0.25)
# Q3 = train['count'].quantile(0.75)
# IQR = Q3 - Q1
# print(IQR)

# %% [raw]
# #2) Q1-1.5IQR과 Q3+1.5IQR을 각각 max와 min으로 설정
# MIN = Q1 - 1.5 * IQR
# MAX = Q3 + 1.5 * IQR
# print(MIN, MAX)

# %% [raw]
# # 3) [min, max]를 벗어나는 데이터는 이상치로 간주하여 제거
# train=train[(train['count']>MIN) & (train['count']<MAX)]
# train

# %% [markdown]
# 'registered'와 'causal'은 생략

# %% [markdown]
# ### (5) Feature, Target 설정
# - train 셋: Feature / Target 으로 분리
#     - 'count','registered','casual'를 target으로
# - test 셋: Feature만 설정

# %%
# train set - features 설정
Xtrain=<blank>   
Xtrain

# %%
# train set -- target 설정 (방법1)
ytrain=train[[<blank>]]
ytrain

# %%
# train set -- target 설정 (방법2)
ytrain=train.iloc[<blank>]
ytrain

# %%
# test set - features
Xtest=test.copy()
Xtest

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### [중요] 만약 범주형데이터가 train셋과 test셋에 다르게 존재한다면 어떻게 될까?
# - Xtrain["weather"]: 4개의 범주값
# - Xtest["weather"]: 3개의 범주값

# %%
print(Xtrain["weather"].unique())
print(Xtest["weather"].unique())

# %%
#### 이 경우 train셋과 test셋이 다르게 인코딩 될 수 있으므로 **합쳐서** 한꺼번에 인코딩!
    - train셋과 test셋 합치기: Xconcat
        - Xtrain: 0~7619(7,620개)
        - Xtest:  0~3265(3,266개)
    - Xconcat으로 총 10,886개 행의 (7,620개+3,266개) df 생성

# %%
Xconcat = pd.concat([Xtrain, Xtest])
Xconcat

# %% [markdown]
# ### (6) 원핫 인코딩 **(feature-질적변수만)**
# - pd.get_dummies(df, columns[해당 column명])
# - 범주형 변수에 대해서 수행

# %%
Xconcat_ohe = pd.get_dummies(Xconcat, 
                         columns = ['year', 'month', 'hour','holiday', 'dayofweek', 'workingday','weather','season'])
Xconcat_ohe

# %%
Xtrain_ohe=Xconcat_ohe[:Xtrain.shape[0]]
Xtrain_ohe

# %%
Xtest_ohe=Xconcat_ohe[Xtrain.shape[0]:]
Xtest_ohe

# %% [markdown]
# - 원핫 인코딩 이후 feature 증가

# %% [markdown]
# ### (7) 스케일링 **(feature-양적변수만)**
# - 스케일링을 통해 변수들의 데이터 분포나 범위를 조정

# %% [markdown]
# **[주의] 스케일링 시 주의사항**
# - fit (스케일링을 위한 계산 수행): train data
# - transform(적용): train data & test data

# %%
from sklearn.preprocessing import StandardScaler

#object 선언
standard_scaler = StandardScaler()

# %%
Xtrain_ohe_scaled=Xtrain_ohe.copy()

# 4개의 양적변수를 모두 standard scaling함 - windspeed의 경우 outlier가 존재하기 때문
Xtrain_ohe_scaled[['temp','atemp','humidity','windspeed']]=standard_scaler.fit_transform(Xtrain_ohe[['temp','atemp','humidity','windspeed']])
Xtrain_ohe_scaled  #스케일링 결과 확인

# %%
Xtest_ohe_scaled=Xtest_ohe.copy()
Xtest_ohe_scaled[['temp','atemp','humidity','windspeed']]=standard_scaler.transform(Xtest_ohe[['temp','atemp','humidity','windspeed']])

Xtest_ohe_scaled  #스케일링 결과 확인

# %% [markdown]
# ##### target 로그 변환
# ![image-2.png](attachment:image-2.png)

# %%
ytrain_log = <blank>

# %%
ytrain_log

# %%
# 로그 변환 후 scale down됨 -ytrain_log의 최대값 확인
ytrain_log.<blank>

# %% [markdown]
# ## [step4] 모델 설계
#  - 모델의 선택 및 학습, 예측, 평가 분석 모델 설계
#  - 다양한 모델의 성능비교 실시
#     - 선형 모델 - LinearRegression
#     - 트리기반 회귀모델 - DecisionTreeRegressor
#     - 트리기반 앙상블 모델 (배깅 기법) - RandomForestRegressor, ExtraTreesRegressor
#     - 트리기반 앙상블 모델 (부스팅 기법) - XGBRegressor, LGBMRegressor

# %% [markdown]
# - 성능을 평가하기 위해 학습 데이터셋에서 20%를 활용해 검증 데이터셋을 생성
#  - test_size = 0.2
#  - random_state = 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (1) 훈련 및 검증 데이터 분할

# %%
# 데이터 분할: test_size=0.2, random_state=0

X_train, X_val, y_train, y_val = train_test_split(Xtrain_ohe_scaled, ytrain_log, test_size=0.2, random_state=0)

# %% [markdown]
# ### (2) 평가지표 확인
# - 평가지표가 RMSLE이므로 해당 함수를 작성해야 함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#실제값과 예측값의 log(x+1)값을 입력값으로 root_mean_scared_error를 구하는 함수 작성

def rmsle(log1p_actual, log1p_pred):
    
    all_rmsle = []
    for i in range(0,3):
        squared_error = (log1p_actual.iloc[:,i]-log1p_pred[:,i])**2   
        rmsle = np.sqrt(np.mean(squared_error))
        all_rmsle.append(rmsle)    
        print('y{}의 RMSLE {:.3f} '.format(i, rmsle))
    
    mean_rmsle = np.mean(all_rmsle)    
    return mean_rmsle

# %% [markdown]
# ### (3) 알고리즘별 학습, 예측, 평가

# %% [markdown]
# - MultiOutputRegressor(estimator명)
#     - 복수개의 target에 대해 해당 estimator로 학습이 가능하게 함

# %% [markdown]
# #### 1) Linear Regression

# %%
# Estimator 설정
lr_reg = <blank>
multioutput_model_lr = MultiOutputRegressor(lr_reg)

#학습
multioutput_model_lr.<blank>

#예측
lr_pred = multioutput_model_lr.<blank>

#평가 - 실제값(y_val)과 예측값(lr_pred)이 모두 log1p처리된 상태임
print('[Linear Regression 모델의 RMSLE]') 
rmsle(y_val, lr_pred)

# %% [markdown]
# #### 2) Decision Tree Regressor

# %%
# 직접 해보세요!

# %% [markdown]
# #### 3) Random Forest Regressor

# %%
# 직접 해보세요! n_jobs=-1

# %% [markdown]
# #### 4) Extra Trees Regressor

# %%
# 직접 해보세요! n_jobs=-1

# %% [markdown]
# #### 5) XGB Regressor

# %%
# 직접 해보세요! verbose=-1,n_jobs=-1

# %% [markdown]
# #### 6) LGBM Regressor

# %%
# 직접 해보세요! verbose=-1,n_jobs=-1

# %% [markdown]
# **[정리] 가장 성능이 좋은 모델을 최종 선정**

# %%
# for문을 이용하여 작성

models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree Regression': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(n_jobs=-1),
    'Extra Trees Regressor': ExtraTreesRegressor(n_jobs=-1),
    'XGB Regressor' : XGBRegressor(verbose=-1,n_jobs=-1),
    'LGBM Regressor' : LGBMRegressor(verbose=-1,n_jobs=-1)
}

# 초기화: selected_estimator, pre_rmsle
selected_estimator = <balnk>
min_rmsle = float('<balnk>')

for name, estimator in models.items():      
    multioutput_estimator = MultiOutputRegressor(<balnk>)
    <balnk>.fit(X_train, y_train)
    pred = <balnk>.predict(X_val)
    rmsle_ = rmsle(y_val, pred)
    print(f'[{name} 모델의 rmsle ]: {round(rmsle_, 3)}')

    if rmsle_ < min_rmsle:
        selected_estimator = multioutput_estimator
        min_rmsle = rmsle_
        print(f'selected estimator: {name}')    
    print('')

# %% [markdown]
# ### (4) 하이퍼 파라미터 튜닝

# %% [markdown]
# - default parameter일때의 성능을 Cross Validation 기반 재검증만 실행!

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# 1) (Cross Validation이 목적이므로) 파라미터 설정은 하지 않음
parameters ={}

# 2) GridSearchCV 설정: 
grid_reg = GridSearchCV(selected_estimator, 
                        parameters,
                        cv=5,
                        scoring=make_scorer(rmsle))

# 3) GridSearchCV estimator로 학습: 
grid_reg.fit(Xtrain_ohe_scaled, ytrain_log)

# 4) Score확인
print('교차 검증 score: ', grid_reg.best_score_)

# %% [markdown]
# ## [step5] 모델 선택 및 적용
# ### (1) test data의 예측값 생성
# - 선정된 최고 성능의 모델로 test data 예측

# %%
pred_test = grid_reg.best_estimator_.predict(Xtest_ohe_scaled)
pred_test

# %% [markdown]
# ### (2) 예측값 스케일 복구 (로그 변환 등으로 필요시)

# %%
pred_test =np.<blank>(pred_test)
pred_test

# %% [markdown]
# ### (3) 실제값과 예측값의 분포 비교 - count만

# %%
fig, axes = plt.<blank>(1, 2, figsize=(15,5))
sns.histplot(x=ytrain.iloc[<blank>], ax=axes[0]) # 실제값 
sns.histplot(x=pred_test[<blank>], ax=axes[1])  # 예측값
plt.show()

# %% [markdown]
# - target의 실제값과 예측값의 분포가 유사함을 확인

# %% [markdown]
# ## [step6] 결과 파일 생성
# ### (1) 예시 파일 불러오기

# %%
#예시 파일 불러오기
submission = pd.read_csv('./data/sampleSubmission_multiout.csv')
submission.head(5)

# %% [markdown]
# ### (2) 예측 결과 저장

# %%
pred_test

# %%
#test data의 예측 결과 저장하기
submission['casual'] = np.round(pred_test[:,<blank>])
submission['registered'] = np.round(pred_test[:,<blank>])
submission['count'] = np.round(pred_test[:,<blank>])
submission.head(3)

# %% [markdown]
# ### (3) 제출할 csv파일 생성

# %%
#제출 파일 생성하기
submission.to_csv('./data/MySubmission_multiout.csv', index=False)

# %% [markdown]
# **수고하셨습니다**
