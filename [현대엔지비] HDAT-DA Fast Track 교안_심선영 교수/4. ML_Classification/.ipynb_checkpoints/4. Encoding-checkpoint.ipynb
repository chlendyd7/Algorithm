# %% [markdown]
# # **원핫 인코딩(One-Hot encoding)**  - <font color='red'>Feature 중 질적변수 대상</font>
# ## 1)레이블 인코딩

# %%
import numpy as np
import pandas as pd

# %%
items=['TV','냉장고','전자렌지','컴퓨터','선풍기','선풍기','믹서','믹서']

# %% [markdown]
# * **LabelEncoder의 객체(class instance) 생성 후, fit( ) 과 transform( ) 으로 label 인코딩**

# %%
from sklearn.<blank> import <blank>

# %% [markdown]
# * **LabelEncoder의 객체 생성**

# %%
encoder = <blank>

# %% [markdown]
# * **전체 데이터의 label 결정(학습)**

# %%
encoder.<blank>(items)

# %% [markdown]
# * **변환(인코딩)**

# %%
encoder.<blank>(items)

# %% [markdown]
# ### [주의!!]
# - 레이블 인코딩 후 숫자값이 부여되므로 이를 머신러닝에 사용하는 경우, 예측 성능이 떨어질 수 있음
# - 냉장고가 1, 믹서가2로 될 경우, 1보다 2가 크다는 의미가 부여되기 때문 (실제로는 단순한 구분용일 뿐)
# - 이러한 이유로 레이블 인코딩은 회귀분석과 같은 머신러닝에서 사용하지 않아야 함
# - 레이블 인코딩의 이러한 문제점을 해결하기 위한 방법이 바로 "원-핫 인코딩" 임!

# %% [markdown]
# - feature값의 유형에 따라 새로운 feature를 추가해 고유값에 해당하는 column에만 1을 나머지 column에는 0을 부여하는 방법

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2)원-핫 인코딩

# %% [markdown]
# * **원-핫 인코딩을 하는 간단한 방법 - pd.get_dummies()**

# %%
import pandas as pd

# %% [markdown]
# * **items를 dataframe으로 생성**

# %%
df = pd.DataFrame(items)
df

# %%
pd.<blank>(df)
