# %% [markdown]
# # 라이브러리 확인 및 필요 라이브러리 설치하기

# %% [markdown]
# # 1. 설치된 라이브러리 확인하기

# %%
# !pip list

# %% [markdown]
# # 2. 라이브러리 설치하여 버전 확인하기
# - xgboost, lightgbm 라이브러리가 있는지 확인하기
#     - import 해보기
#     - version 확인하기

# %% [markdown]
# ## (1) 라이브러리 설치하기 (필요시)
# - !pip install 라이브러리명

# %%
# !pip install xgboost

# %%
# !pip install lightgbm

# %% [markdown]
# ## (2) 라이브러리 import

# %%
#XGB 불러오기
import xgboost

#LGBM 불러오기
import lightgbm

# %% [markdown]
# ## (3)  라이브러리 버전 확인
#  - 라이브러리명.\__version__ (underbar 2개씩)

# %%
# xgboost 라이브러리 버젼을 확인해 봅시다.
xgboost.__version__

# %%
# lightgbm 라이브러리 버젼을 확인해 봅시다.
lightgbm.<blank>

# %%
#pandas 버젼을 확인해 봅시다.
<blank>

# %% [markdown]
# ***** **수고하셨습니다.** ***********
