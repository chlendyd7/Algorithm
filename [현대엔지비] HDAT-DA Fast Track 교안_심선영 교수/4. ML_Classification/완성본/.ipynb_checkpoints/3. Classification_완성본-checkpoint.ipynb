# %% [markdown]
# # 분류 모델링 실습

# %% [markdown]
# ## 위스콘신 유방암 데이터 예측
# ### 종양의 크기, 모양 등 다양한 속성값을 기반으로 유방암 양성인지 음성인지를 분류함

# %% [markdown]
# ![image.png](attachment:d2b9bc9d-4e81-4b26-b51e-3ff2ad63fc85.png)

# %% [markdown]
# ## 실습 순서 이해
# 다음 순서로 실습을 해 본다.
# - (1) 라이브러리/모듈 import
# - (2) 위스콘신 유방암 데이터 세트 호출 (load_breast_cancer())
# - (3) 데이터를 학습데이터와 테스트 데이터로 분리
# - (4) 분석 모델 적용
#     - 로지스틱 회귀, K-nn, Decision Tree
#     - RandomForest, Extratree, XGB, LBGM 등 분류모델 사용

# %% [markdown]
# ### 1) 라이브러리/모듈 import

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2) 데이터 로드 & Dataframe으로 변환

# %%
df = pd.read_csv('cancer.csv')
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# ### feature 30개열 + target 1개열

# %%
#X와 y를 분리해 봅니다.

X= df.drop('target', axis=1)
y= df['target']

# %% [markdown]
# ### X->2d (dataframe)
# ### y->1d (series)

# %%
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: target, Length: 569, dtype: int64

# %% [markdown]
# ### 3) 학습과 검증 데이터 셋 분리
# - train_test_split을 이용한다.
# - 단, X_train, X_val, y_train, y_val으로 설정
# - test_size=0.2

# %%
#train_test_split을 이용하여 훈련용과 검증용을 나눕니다. 
#(test_size =0.2, random_sate = 156)

X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.2 , random_state= 156)

# %% [markdown]
# ### 4) 개별모델로 학습/예측/성능평가
# #### 1) LogisticRegression
# - 로지스틱회귀분석 실시한다.

# %%
#로지스틱 회귀 class import
from sklearn.linear_model import LogisticRegression

# %%
# 객체생성
lr_clf = LogisticRegression()   

# 학습 
lr_clf.fit(X_train , y_train)

# 예측 
pred_lr = lr_clf.predict(X_val)

# 성능평가 - accuracy  
accuracy_score(y_val , pred_lr)
# Out:
# 0.9385964912280702

# %% [markdown]
# #### 2) KNN

# %%
#K-nn class import

from sklearn.neighbors import KNeighborsClassifier

# %%
# 객체생성
knn_clf = KNeighborsClassifier(n_neighbors=8)

# 학습 
knn_clf.fit(X_train, y_train)

# 예측 
pred_knn = knn_clf.predict(X_val)

# 성능평가
accuracy_score(y_val , pred_knn)
# Out:
# 0.9385964912280702

# %%
for i in range(1,11):
    knn_clf = KNeighborsClassifier(n_neighbors=i)
    knn_clf.fit(X_train, y_train)
    pred_knn=knn_clf.predict(X_val)
    accuracy_knn = accuracy_score(y_val , pred_knn)
    print('k= {:d} 일 때 KNN 정확도: {:.4f}'.format(i, accuracy_knn))
# Out:
# k= 1 일 때 KNN 정확도: 0.9211
# k= 2 일 때 KNN 정확도: 0.8947
# k= 3 일 때 KNN 정확도: 0.9035
# k= 4 일 때 KNN 정확도: 0.9211
# k= 5 일 때 KNN 정확도: 0.9035
# k= 6 일 때 KNN 정확도: 0.9211
# k= 7 일 때 KNN 정확도: 0.9474
# k= 8 일 때 KNN 정확도: 0.9386
# k= 9 일 때 KNN 정확도: 0.9649
# k= 10 일 때 KNN 정확도: 0.9474

# %% [markdown]
# #### 3) DecisionTree

# %%
#Decision Tree class import
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# - "blank"에 알맞은 메소드 넣기

# %%
# 객체생성
dt_clf = DecisionTreeClassifier()

# 학습
dt_clf.fit(X_train , y_train)

# 예측
pred = dt_clf.predict(X_val)

# 평가
accuracy_score(y_val , pred)
# Out:
# 0.9473684210526315

# %% [markdown]
# #### 4) 랜덤 포레스트의 학습/ 예측 / 평가

# %%
#Random Forest class import
from sklearn.ensemble import RandomForestClassifier

# %%
# 객체생성
rf_clf = RandomForestClassifier()

# 학습
rf_clf.fit(X_train , y_train)

# 예측 
pred = rf_clf.predict(X_val)

# 평가
accuracy = accuracy_score(y_val, pred)

# %% [markdown]
# #### 5) ExtraTreesClassifier

# %%
#ExtraTrees class import
from sklearn.ensemble import ExtraTreesClassifier

# %%
#직접 해 보세요!
# 객체생성
ex_clf = ExtraTreesClassifier(random_state=0)

# 학습   
ex_clf.fit(X_train, y_train)

# 예측 
pred = ex_clf.predict(X_val)   

# 평가
accuracy_score(y_val, pred)
# Out:
# 0.9473684210526315

# %% [markdown]
# #### 6) XGB

# %%
#XGB class import
from xgboost import XGBClassifier

# %%
# 객체생성
xgb_clf = XGBClassifier()

# 학습
xgb_clf.fit(X_train , y_train)

# 예측
pred = xgb_clf.predict(X_val)

# 평가
accuracy_score(y_val, pred)
# Out:
# 0.9649122807017544

# %% [markdown]
# #### 7) LGBM

# %%
#LGBM class import
from lightgbm import LGBMClassifier

# %%
X_train
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 172       15.460         11.89          102.50      736.9          0.12570
# 160       11.750         20.18           76.10      419.8          0.10890
# 173       11.080         14.71           70.21      372.7          0.10060
# 504        9.268         12.87           61.49      248.7          0.16340
# 476       14.200         20.53           92.41      618.4          0.08931
# ..           ...           ...             ...        ...              ...
# 55        11.520         18.75           73.34      409.0          0.09524
# 10        16.020         23.24          102.70      797.8          0.08206
# 485       12.450         16.41           82.85      476.7          0.09514
# 418       12.700         12.17           80.88      495.0          0.08785
# 556       10.160         19.59           64.73      311.7          0.10030
#
# ...

# %%
# estimator생성
lgb_clf = LGBMClassifier(verbose=-1)

# 학습
lgb_clf.fit(X_train , y_train)

# 예측 
pred = lgb_clf.predict(X_val)

#평가
accuracy_score(y_val, pred)
# Out:
# 0.956140350877193

# %% [markdown]
# ## 분류모델의 평가지표 - accuracy, precision, recall, f1
# ### confusion matrix

# %%
#confusion matrix 
from sklearn.metrics import confusion_matrix 

confusion_matrix(y_val, pred)   #실제값, 예측값
# Out:
# array([[33,  4],
#        [ 1, 76]], dtype=int64)

# %% [markdown]
# ### accuracy_score, precision_score, recall_score, f1_score

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
#accuracy
accuracy_score(y_val,pred)
# Out:
# 0.956140350877193

# %%
#precision
precision_score(y_val,pred)
# Out:
# 0.95

# %%
#recall
recall_score(y_val, pred)
# Out:
# 0.987012987012987

# %%
#f1
f1_score(y_val, pred)
# Out:
# 0.9681528662420381
