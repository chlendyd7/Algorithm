# %% [markdown]
# # SOH Class 예측 AI모델 개발
#
# ## 개요
# - 리튬이온 배터리의 건강상태(State-of-health: SOH)의 등급(Class) 추정 AI모델 개발

# %% [markdown]
# ## 분석배경
# - 리튬이온 배터리는 충/방전 동작 및 저장 환경에 따라 전극 노화 및 반응 가능한 리튬이온의 감소로 사용 가능한 용량이 감소합니다.
# - 사용 가능한 용량의 감소는 리튬이온 배터리가 사용되는 어플리케이션(전기자동차, 에너지저장장치 등)의 사용 시간을 감소시키는 매우 중요한 모니터링 인자로, 이를 건강상태(State-of-health: SOH)라고 합니다.
# - 하지만, 리튬이온 배터리의 사용에 따른 노화를 추정하기 위해서는 비선형적인 배터리의 동작 특성에 따른 지표 선정과 이를 효율적으로 반영할 수 있는 분석 방법이 필요하며
# - 이를 바탕으로 리튬이온 배터리의 건강상태(State-of-health: SOH)의 등급(Class)을 추정하여 분류할 수 있는 AI 모델을 개발하고자 합니다.

# %% [markdown]
# ## 평가 지표
# - accuracy (정확도)

# %% [markdown]
# ## 데이터 셋 정보

# %% [markdown]
# ### [Data Files]
# - train.csv: 학습용 데이터 (Features, Target) - 50,000건
# - test.csv:  예측용 데이터 (Features) - 50,000건

# %% [markdown]
# ### [Feature]
# - V0 ~ V7

# %% [markdown]
# ### [Target]
# - Class: 리튬이온 배터리의 건강상태 (0~4)

# %% [markdown]
# ## 분석단계
# - **[step1] 라이브러리 및 데이터 불러오기**
#  - (1) 라이브러리 불러오기
#  - (2) 데이터 불러오기
#  - (3) 데이터 확인
# - **[step2] 탐색적 데이터 분석 (EDA)**
#  - (1) 기술적 통계분석
#  - (2) 변수별 분포 시각화
# - **[step3] 데이터 전처리**
#  - (1) 중복값 처리 **(Train셋만)**
#  - (2) 불필요한 Feature삭제 (ID 등)
#  - (3) 결측치 처리
#  - (4) 아웃라이어 제거 **(Train셋 & 양적변수만)**
#  - (5) Feature, Target 설정
#  - (6) 원핫 인코딩 **(feature-질적변수만)**
#  - (7) 스케일링 **(feature-양적변수만)**
# - **[step4] 모델 설계**
#  - (1) 훈련 및 검증 데이터 분할
#  - (2) 평가지표 확인
#  - (3) 알고리즘별 학습, 예측, 평가
# - **[step5] 모델 선택 및 적용**
#  - (1) test data의 예측값 생성
# - **[step6] 결과 파일 생성**
#  - (1) 예시 파일 불러오기
#  - (2) test data의 예측 결과 저장
#  - (3) 제출할 csv파일 생성

# %% [markdown]
# ## [Step1] 불러오기

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %%
# 데이터분석 라이브러리 불러오기
import pandas as pd
import numpy as np

#시각화를 위한 라이브러리 불러오기 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#AI모델 사용을 위한 라이브러리 불러오기
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import ExtraTreesClassifier 

from xgboost import XGBClassifier 
from lightgbm import LGBMClassifier

#모델링을 위한 함수 불러오기 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#future warning filter 불러오기
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### (2) 데이터 불러오기
# **train data**

# %%
train = pd.read_csv('./train.csv')

# %%
train.head()
# Out:
#             ID        V0        V1        V2        V3        V4        V5  \
# 0  TRAIN_00000       NaN -0.063437 -0.083507  0.475347 -0.012022 -0.121974
# 1  TRAIN_00001 -0.271026 -0.145173       NaN       NaN  0.012653 -0.092344
# 2  TRAIN_00002 -1.035352       NaN -0.034443 -0.530655  0.001150  0.023062
# 3  TRAIN_00003 -0.694365       NaN  0.071421  0.102912  0.399999       NaN
# 4  TRAIN_00004       NaN -0.092620  0.113638  0.104676 -0.031853  0.041083
#
#          V6        V7  Class
# 0       NaN  0.047851      1
# 1 -0.030913 -0.052701      3
# 2 -0.012697  0.058407      3
# 3  0.094365       NaN      0
# 4 -0.146752 -0.123120      3

# %% [markdown]
# **test data**

# %%
#정답
test = pd.read_csv('./test.csv')

# %%
# test data 확인
test.head()
# Out:
#            ID       V0        V1        V2        V3        V4        V5  \
# 0  TEST_00000  0.43832  0.008664 -0.108562  0.080903  0.018390  0.150824
# 1  TEST_00001      NaN  0.025618       NaN -0.012339 -0.011225 -0.052003
# 2  TEST_00002      NaN -0.072010  0.089537 -0.024380  0.011646 -0.318628
# 3  TEST_00003      NaN -0.262615  0.142379 -0.091961 -0.154997  0.224558
# 4  TEST_00004      NaN -0.415798       NaN       NaN  0.079869  0.275429
#
#          V6        V7
# 0  0.315389 -0.119679
# 1 -0.000759  0.023875
# 2 -0.225632  0.253589
# 3       NaN       NaN
# 4  0.269511  0.024939

# %% [markdown]
# ### (3) 데이터 확인
#  - df.info()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      50000 non-null  object
#  1   V0      39951 non-null  float64
#  2   V1      40013 non-null  float64
#  3   V2      40159 non-null  float64
#  4   V3      39836 non-null  float64
#  5   V4      40053 non-null  float64
#  6   V5      40062 non-null  float64
#  7   V6      39990 non-null  float64
#  8   V7      39974 non-null  float64
#  9   Class   50000 non-null  int64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 3.8+ MB

# %%
#정답
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      50000 non-null  object
#  1   V0      40135 non-null  float64
#  2   V1      39993 non-null  float64
#  3   V2      40007 non-null  float64
#  4   V3      39950 non-null  float64
#  5   V4      39963 non-null  float64
#  6   V5      40144 non-null  float64
#  7   V6      39957 non-null  float64
#  8   V7      39870 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.4+ MB

# %% [markdown]
# ## [Step2] 탐색적 데이터 분석 (EDA)

# %% [markdown]
# ### (1) 기술통계분석
# - describe()를 이용한 통계치 확인

# %%
train.describe()
# Out:
#                  V0            V1            V2            V3            V4  \
# count  39951.000000  40013.000000  40159.000000  39836.000000  40053.000000
# mean      -0.002170      0.001493     -0.000191      0.000611      0.000455
# std        0.616873      0.176340      0.166273      0.163593      0.162170
# min       -1.167258     -0.754546     -0.995570     -0.793750     -0.776659
# 25%       -0.490101     -0.099416     -0.070225     -0.018816     -0.019721
# 50%       -0.067643     -0.016537      0.003078     -0.000092     -0.000222
# 75%        0.457345      0.100593      0.078064      0.020320      0.017189
# max        1.518668      0.977665      1.025999      0.772125      0.791807
#
#                  V5            V6            V7         Class
# count  40062.000000  39990.000000  39974.000000  50000.000000
# mean       0.000572     -0.000358      0.000817      2.313260
# std        0.159810      0.151977      0.151217      1.338418
# min       -0.785080     -0.711145     -0.708901      0.000000
# 25%       -0.090024     -0.019932     -0.044479      1.000000
# 50%        0.000912     -0.000230     -0.003676      2.000000
# 75%        0.082559      0.018993      0.050770      3.000000
# max        0.861973      0.709650      0.795469      4.000000

# %%
test.describe()
# Out:
#                  V0            V1            V2            V3            V4  \
# count  40135.000000  39993.000000  40007.000000  39950.000000  39963.000000
# mean      -0.000200     -0.001290      0.000097     -0.000688     -0.001125
# std        0.611764      0.177132      0.167650      0.163555      0.162287
# min       -1.167289     -0.666994     -0.977027     -0.790033     -0.776417
# 25%       -0.480197     -0.100948     -0.069903     -0.019424     -0.020284
# 50%       -0.069719     -0.019145      0.003568     -0.000187     -0.000342
# 75%        0.453820      0.099168      0.079534      0.020902      0.016438
# max        1.506129      0.937866      1.087868      0.796121      0.794851
#
#                  V5            V6            V7
# count  40144.000000  39957.000000  39870.000000
# mean      -0.000312      0.000299     -0.001379
# std        0.158076      0.150890      0.149783
# min       -0.883172     -0.742959     -0.719021
# 25%       -0.087962     -0.019091     -0.046182
# 50%        0.000776      0.000168     -0.004580
# 75%        0.080337      0.019319      0.048616
# max        0.866021      0.752653      0.822374

# %% [markdown]
# ### (2) 변수별 분포 시각화
# #### 1) 변수들간 상관관계를 보여주는 pairplot

# %%
#정답예시
plt.figure(figsize = (15,15))
sns.pairplot(train) 
#또는 sns.pairplot(train,hue='Class' ), 또는 sns.pairplot(train[['V0', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'Class']])

plt.show()

# %% [markdown]
# **[정리] 변수들간 선형관계가 없는 것을 확인할 수 있다**

# %% [markdown]
# #### 2) 연속형 (양적) 변수의 분포를 보여주는 histplot
# - V0~V7

# %%
#정답
fig, axes = plt.subplots(2, 4, figsize=(20,10))

sns.histplot(x = train['V0'], ax=axes[0][0])
sns.histplot(x = train['V1'], ax=axes[0][1])
sns.histplot(x = train['V2'], ax=axes[0][2])
sns.histplot(x = train['V3'], ax=axes[0][3])
sns.histplot(x = train['V4'], ax=axes[1][0])
sns.histplot(x = train['V5'], ax=axes[1][1])
sns.histplot(x = train['V6'], ax=axes[1][2])
sns.histplot(x = train['V7'], ax=axes[1][3])
plt.show()

# %% [markdown]
# #### 3) 범주형 (질적) 변수의 빈도를 보여주는 countplot
# - Class(target)

# %%
sns.countplot(x = train['Class']).set_title('Class')
# Out:
# Text(0.5, 1.0, 'Class')

# %% [markdown]
#  - Class의 경우에는 큰 불균형 없음

# %% [markdown]
# ## [step3] 데이터 전처리

# %% [markdown]
# ### (1) 중복값 처리 **(Train셋만)**

# %%
# train 셋의 중복값 확인
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### [주의1]
# - 만약 train data 에 중복값이 있다면?
#     - df.drop_duplicates()를 이용하여 중복행을 제거
#     - 회귀 파트에서 다룰 예정
#
# ##### [주의2]
# - test 셋의 경우 예측 후 제출 파일과 데이터 건수가 동일해야 함
# - 따라서 **test 셋에 대해서는 중복에 의한 제거처리를 하지 않음**

# %% [markdown]
# ### (2) 불필요한 Feature 삭제

# %%
# ID column 삭제 -train set
train.drop(['ID'], axis=1, inplace=True)
train
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0           NaN -0.063437 -0.083507  0.475347 -0.012022 -0.121974       NaN
# 1     -0.271026 -0.145173       NaN       NaN  0.012653 -0.092344 -0.030913
# 2     -1.035352       NaN -0.034443 -0.530655  0.001150  0.023062 -0.012697
# 3     -0.694365       NaN  0.071421  0.102912  0.399999       NaN  0.094365
# 4           NaN -0.092620  0.113638  0.104676 -0.031853  0.041083 -0.146752
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.897280  0.198602  0.027603  0.125120  0.300453       NaN -0.105906
# 49996       NaN -0.020727 -0.030771       NaN  0.005013       NaN  0.032835
# 49997  0.582378 -0.018754 -0.012226 -0.011277       NaN -0.028654  0.003075
# 49998       NaN  0.114867 -0.015775  0.012714 -0.015274  0.143736  0.088785
# 49999 -0.478494  0.107630  0.137241  0.251064  0.051913  0.110788 -0.078830
#
#              V7  Class
# 0      0.047851      1
# 1     -0.052701      3
# 2      0.058407      3
# 3           NaN      0
# 4     -0.123120      3
# ...         ...    ...
# 49995  0.056823      4
# 49996  0.118511      2
# 49997       NaN      1
# 49998 -0.110537      4
# 49999 -0.049728      1
#
# [50000 rows x 9 columns]

# %%
# ID column 삭제 -test set
test.drop(['ID'], axis=1, inplace=True)
test
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0      0.438320  0.008664 -0.108562  0.080903  0.018390  0.150824  0.315389
# 1           NaN  0.025618       NaN -0.012339 -0.011225 -0.052003 -0.000759
# 2           NaN -0.072010  0.089537 -0.024380  0.011646 -0.318628 -0.225632
# 3           NaN -0.262615  0.142379 -0.091961 -0.154997  0.224558       NaN
# 4           NaN -0.415798       NaN       NaN  0.079869  0.275429  0.269511
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.132452  0.281816  0.228475 -0.261477  0.549440  0.635909 -0.186036
# 49996  0.705232 -0.012156  0.006206 -0.273154       NaN -0.086448  0.282508
# 49997 -0.388839  0.084974  0.145287 -0.420798       NaN  0.270230 -0.098514
# 49998  1.133047  0.124206       NaN -0.007631  0.007239  0.043837       NaN
# 49999  0.164680       NaN  0.055532  0.109360 -0.120764  0.079762 -0.001921
#
#              V7
# 0     -0.119679
# 1      0.023875
# 2      0.253589
# 3           NaN
# 4      0.024939
# ...         ...
# 49995  0.171476
# 49996       NaN
# 49997 -0.086113
# 49998  0.067809
# 49999  0.051925
#
# [50000 rows x 8 columns]

# %% [markdown]
# ### (3) 결측치 처리

# %% [markdown]
# - train과 test의 결측치 확인

# %%
# train data의 결측치 확인
train.isnull().sum()
# Out:
# V0       10049
# V1        9987
# V2        9841
# V3       10164
# V4        9947
# V5        9938
# V6       10010
# V7       10026
# Class        0
# dtype: int64

# %%
# test- train과 test의 결측치 확인 data의 결측치 확인
test.isnull().sum()
# Out:
# V0     9865
# V1    10007
# V2     9993
# V3    10050
# V4    10037
# V5     9856
# V6    10043
# V7    10130
# dtype: int64

# %% [markdown]
# - 만약 train['Class'], 즉 **target 에 결측**이 있다면?
#     - 이는 평균으로 대체할 대상이 아님
#     - 해당 행을 미리 제거해야 함

# %%
train['Class'].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 49995    True
# 49996    True
# 49997    True
# 49998    True
# 49999    True
# Name: Class, Length: 50000, dtype: bool

# %%
#train['Class']이 결측인 행 제거
train=train[train['Class'].notnull()]
train
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0           NaN -0.063437 -0.083507  0.475347 -0.012022 -0.121974       NaN
# 1     -0.271026 -0.145173       NaN       NaN  0.012653 -0.092344 -0.030913
# 2     -1.035352       NaN -0.034443 -0.530655  0.001150  0.023062 -0.012697
# 3     -0.694365       NaN  0.071421  0.102912  0.399999       NaN  0.094365
# 4           NaN -0.092620  0.113638  0.104676 -0.031853  0.041083 -0.146752
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.897280  0.198602  0.027603  0.125120  0.300453       NaN -0.105906
# 49996       NaN -0.020727 -0.030771       NaN  0.005013       NaN  0.032835
# 49997  0.582378 -0.018754 -0.012226 -0.011277       NaN -0.028654  0.003075
# 49998       NaN  0.114867 -0.015775  0.012714 -0.015274  0.143736  0.088785
# 49999 -0.478494  0.107630  0.137241  0.251064  0.051913  0.110788 -0.078830
#
#              V7  Class
# 0      0.047851      1
# 1     -0.052701      3
# 2      0.058407      3
# 3           NaN      0
# 4     -0.123120      3
# ...         ...    ...
# 49995  0.056823      4
# 49996  0.118511      2
# 49997       NaN      1
# 49998 -0.110537      4
# 49999 -0.049728      1
#
# [50000 rows x 9 columns]

# %% [markdown]
# - train - **Feature** 의 결측치를 각 변수의 평균치로 대체
#  - df.fillna()
#  - df.mean()

# %%
train=train.fillna(train.mean())

# %% [markdown]
# - [주의] test 셋의 결측치도 **train 셋** 각 변수의 평균치로 대체합니다!

# %%
test=test.fillna(train.mean())

# %% [raw]
# #[참고] 상기의 소스 코드는 아래와 동일한 효과를 냄
#
# #train 셋
# train['V0'] = train['V0'].fillna(train['V0'].mean())
# train['V1'] = train['V1'].fillna(train['V1'].mean())
# train['V2'] = train['V2'].fillna(train['V2'].mean())
# train['V3'] = train['V3'].fillna(train['V3'].mean())
# train['V4'] = train['V4'].fillna(train['V4'].mean())
# train['V5'] = train['V5'].fillna(train['V5'].mean())
# train['V6'] = train['V6'].fillna(train['V6'].mean())
# train['V7'] = train['V7'].fillna(train['V7'].mean())
#
# #test셋
# test['V0'] = test['V0'].fillna(train['V0'].mean())
# test['V1'] = test['V1'].fillna(train['V1'].mean())
# test['V2'] = test['V2'].fillna(train['V2'].mean())
# test['V3'] = test['V3'].fillna(train['V3'].mean())
# test['V4'] = test['V4'].fillna(train['V4'].mean())
# test['V5'] = test['V5'].fillna(train['V5'].mean())
# test['V6'] = test['V6'].fillna(train['V6'].mean())
# test['V7'] = test['V7'].fillna(train['V7'].mean())

# %% [markdown]
# - 결측치 처리가 되었음을 확인

# %%
#정답
# train data 결측치 대체 완료 확인 
train.isnull().sum()
# Out:
# V0       0
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# Class    0
# dtype: int64

# %%
#정답
# test data 결측치 대체 완료 확인 
test.isnull().sum()
# Out:
# V0    0
# V1    0
# V2    0
# V3    0
# V4    0
# V5    0
# V6    0
# V7    0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V0      50000 non-null  float64
#  1   V1      50000 non-null  float64
#  2   V2      50000 non-null  float64
#  3   V3      50000 non-null  float64
#  4   V4      50000 non-null  float64
#  5   V5      50000 non-null  float64
#  6   V6      50000 non-null  float64
#  7   V7      50000 non-null  float64
#  8   Class   50000 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 3.4 MB

# %% [markdown]
# ### (4) 아웃라이어 제거  **(Train셋 & 양적변수만)**
# - **[데이터셋]**
#     - **train셋** 에 적용
#     - train셋은 모델이 일반화된 패턴을 배우는 구간, 아웃라이어가 모델 학습에 악영향을 줄 수 있기 때문에 **아웃라이어 제거**
#     - test셋은 모델의 성능을 평가하기 위한 처음 접하는(unseen) 데이터, **test 데이터 손대지 않음**
# - **[대상 변수]**
#     - **target** 아웃라이어 처리
#         - 회귀모델에서 target의 극단적인 값은 모델 왜곡 가능, 예측 성능에 큰 영향
#     - **feature** 아웃라이어 처리
#         - feature 아웃라이어도 모델 학습에 영향 가능(특히 **target과 강한 상관관계** 때)
#         - 하지만, 모든 feature를 다 아웃라이어 처리하다보면 데이터 유실이 심해짐
#         - **일단 모델링을 하고 feature importance 뽑아서 후처리**도 전략
#             - 영향력 높은 feature만 따로 아웃라이어 처리
# - **[아웃라이어 제거 순위]**
#   - 1순위: train셋의 target(**회귀모델**일 경우)
#   - 2순위: train셋의 feature
#   - 단, 변수의 아웃라이어가 자연스러운 변동일 경우에는 제거하지 않는 것이 좋으므로 신중하게 수행

# %%
# 분류모델이므로 train셋의 feature를 대상으로 아웃라이어 확인 - boxplotting
sns.boxplot(data=train[["V0","V1","V3","V4","V5","V6","V7"]])
plt.show()

# %%
#'V0'에서 상단 아웃라이어 제거 -  train['V0']<=1.5 인 데이터만 남김
train=train[train['V0']<=1.5 ]
train   # 50,000개 --> ??개
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0     -0.002170 -0.063437 -0.083507  0.475347 -0.012022 -0.121974 -0.000358
# 1     -0.271026 -0.145173 -0.000191  0.000611  0.012653 -0.092344 -0.030913
# 2     -1.035352  0.001493 -0.034443 -0.530655  0.001150  0.023062 -0.012697
# 3     -0.694365  0.001493  0.071421  0.102912  0.399999  0.000572  0.094365
# 4     -0.002170 -0.092620  0.113638  0.104676 -0.031853  0.041083 -0.146752
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.897280  0.198602  0.027603  0.125120  0.300453  0.000572 -0.105906
# 49996 -0.002170 -0.020727 -0.030771  0.000611  0.005013  0.000572  0.032835
# 49997  0.582378 -0.018754 -0.012226 -0.011277  0.000455 -0.028654  0.003075
# 49998 -0.002170  0.114867 -0.015775  0.012714 -0.015274  0.143736  0.088785
# 49999 -0.478494  0.107630  0.137241  0.251064  0.051913  0.110788 -0.078830
#
#              V7  Class
# 0      0.047851      1
# 1     -0.052701      3
# 2      0.058407      3
# 3      0.000817      0
# 4     -0.123120      3
# ...         ...    ...
# 49995  0.056823      4
# 49996  0.118511      2
# 49997  0.000817      1
# 49998 -0.110537      4
# 49999 -0.049728      1
#
# [49985 rows x 9 columns]

# %% [markdown]
# ### (5) Feature, Target 설정
# - train 셋: Feature / Target 으로 분리
# - test 셋: Feature만 설정

# %%
# train set - features 설정
Xtrain=train.drop(['Class'], axis=1)
Xtrain
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0     -0.002170 -0.063437 -0.083507  0.475347 -0.012022 -0.121974 -0.000358
# 1     -0.271026 -0.145173 -0.000191  0.000611  0.012653 -0.092344 -0.030913
# 2     -1.035352  0.001493 -0.034443 -0.530655  0.001150  0.023062 -0.012697
# 3     -0.694365  0.001493  0.071421  0.102912  0.399999  0.000572  0.094365
# 4     -0.002170 -0.092620  0.113638  0.104676 -0.031853  0.041083 -0.146752
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.897280  0.198602  0.027603  0.125120  0.300453  0.000572 -0.105906
# 49996 -0.002170 -0.020727 -0.030771  0.000611  0.005013  0.000572  0.032835
# 49997  0.582378 -0.018754 -0.012226 -0.011277  0.000455 -0.028654  0.003075
# 49998 -0.002170  0.114867 -0.015775  0.012714 -0.015274  0.143736  0.088785
# 49999 -0.478494  0.107630  0.137241  0.251064  0.051913  0.110788 -0.078830
#
#              V7
# 0      0.047851
# 1     -0.052701
# 2      0.058407
# 3      0.000817
# 4     -0.123120
# ...         ...
# 49995  0.056823
# 49996  0.118511
# 49997  0.000817
# 49998 -0.110537
# 49999 -0.049728
#
# [49985 rows x 8 columns]

# %%
# train set -- target 설정
ytrain=train['Class']
ytrain
# Out:
# 0        1
# 1        3
# 2        3
# 3        0
# 4        3
#         ..
# 49995    4
# 49996    2
# 49997    1
# 49998    4
# 49999    1
# Name: Class, Length: 49985, dtype: int64

# %%
# test set - features
Xtest=test.copy()
Xtest
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0      0.438320  0.008664 -0.108562  0.080903  0.018390  0.150824  0.315389
# 1     -0.002170  0.025618 -0.000191 -0.012339 -0.011225 -0.052003 -0.000759
# 2     -0.002170 -0.072010  0.089537 -0.024380  0.011646 -0.318628 -0.225632
# 3     -0.002170 -0.262615  0.142379 -0.091961 -0.154997  0.224558 -0.000358
# 4     -0.002170 -0.415798 -0.000191  0.000611  0.079869  0.275429  0.269511
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.132452  0.281816  0.228475 -0.261477  0.549440  0.635909 -0.186036
# 49996  0.705232 -0.012156  0.006206 -0.273154  0.000455 -0.086448  0.282508
# 49997 -0.388839  0.084974  0.145287 -0.420798  0.000455  0.270230 -0.098514
# 49998  1.133047  0.124206 -0.000191 -0.007631  0.007239  0.043837 -0.000358
# 49999  0.164680  0.001493  0.055532  0.109360 -0.120764  0.079762 -0.001921
#
#              V7
# 0     -0.119679
# 1      0.023875
# 2      0.253589
# 3      0.000817
# 4      0.024939
# ...         ...
# 49995  0.171476
# 49996  0.000817
# 49997 -0.086113
# 49998  0.067809
# 49999  0.051925
#
# [50000 rows x 8 columns]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### (6) 원핫 인코딩 **(feature-질적변수만)**
# - get_dummies(df, columns=[해당 column명])
# - **feature** 중 **카테고리 변수**에 대해서 수행
# - 하지만 본 프로젝트에서는 feature에 카테고리 변수가 없으므로 이 과정을 생략

# %%
# 본 프로젝트에서는 필요없는 과정이나 향후 원핫인코딩이 필요한 분류문제를 위해 이 과정을 남겨둠
# 현재는 원핫인코딩이 필요없으므로 기존 df을 단순 복사만 해둠
#실제 필요시 처리과정은 회귀파트에 다룰 예정
Xtrain_ohe=Xtrain.copy()  
Xtest_ohe=Xtest.copy()

# %% [markdown]
# ### (7) 스케일링 **(feature-양적변수만)**
# - 스케일링을 통해 변수들의 데이터 분포나 범위를 조정

# %% [markdown]
# **[주의] 스케일링 시 주의사항**
# - fit (스케일링을 위한 계산 수행): train data
# - transform(적용): train data & test data

# %% [markdown]
# **train data**
# ###### 1) MinMaxScaling
# - 스케일후df= minmax_scaler.**fit_transform**(스케일전df)
#
# ###### 2) StandardScaling
# - 스케일후df= standard_scaler.**fit_transform**(스케일전df)

# %%
from sklearn.preprocessing import StandardScaler

#object 선언
standard_scaler = StandardScaler()

# %%
# 결과 DF를 미리 생성
Xtrain_ohe_scaled=Xtrain_ohe.copy()

# 스케일링이 필요한 변수만 나열
Xtrain_ohe_scaled[['V0','V1','V2','V3','V4','V5','V6','V7']]=standard_scaler.fit_transform(Xtrain_ohe[['V0','V1','V2','V3','V4','V5','V6','V7']])
Xtrain_ohe_scaled  #스케일링 결과 확인
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0      0.000821 -0.411470 -0.559119  3.251478 -0.085993 -0.856574  0.000008
# 1     -0.487238 -0.929665 -0.000059  0.000106  0.083984 -0.649443 -0.224773
# 2     -1.874733  0.000173 -0.229896 -3.638424  0.004746  0.157306 -0.090765
# 3     -1.255733  0.000173  0.480469  0.700744  2.752377  0.000086  0.696845
# 4      0.000821 -0.596488  0.763748  0.712827 -0.222614  0.283285 -1.076957
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -1.624088  1.249804  0.186440  0.852845  2.066612  0.000086 -0.776468
# 49996  0.000821 -0.140700 -0.205257  0.000106  0.031353  0.000086  0.244195
# 49997  1.061962 -0.128190 -0.080816 -0.081312 -0.000042 -0.204215  0.025259
# 49998  0.000821  0.718941 -0.104631  0.083000 -0.108397  1.000886  0.655798
# 49999 -0.863859  0.673062  0.922127  1.715411  0.354444  0.770561 -0.577279
#
#              V7
# 0      0.347819
# 1     -0.395766
# 2      0.425881
# 3      0.000002
# 4     -0.916520
# ...         ...
# 49995  0.414170
# 49996  0.870354
# 49997  0.000002
# 49998 -0.823465
# 49999 -0.373780
#
# [49985 rows x 8 columns]

# %%
Xtrain_ohe_scaled.min()
# Out:
# V0   -2.114185
# V1   -4.792968
# V2   -6.679173
# V3   -5.440303
# V4   -5.353506
# V5   -5.492041
# V6   -5.228976
# V7   -5.248394
# dtype: float64

# %%
Xtrain_ohe_scaled.max()
# Out:
# V0    2.727678
# V1    6.188913
# V2    6.885805
# V3    5.284051
# V4    5.451505
# V5    6.021747
# V6    5.223261
# V7    5.876496
# dtype: float64

# %% [markdown]
# **test data**
# ###### 1) MinMaxScaling
# - 스케일후df= minmax_scaler.**transform**(스케일전df)
#
# ###### 2) StandardScaling
# - 스케일후df= standard_scaler.**transform**(스케일전df)

# %%
# test 셋의 결과 DF 미리 생성
Xtest_ohe_scaled = Xtest_ohe.copy()

# %%
Xtest_ohe_scaled[['V0','V1','V2','V3','V4','V5','V6','V7']]=standard_scaler.transform(Xtest_ohe[['V0','V1','V2','V3','V4','V5','V6','V7']])
Xtest_ohe_scaled  #스케일링 결과 확인
# Out:
#              V0        V1        V2        V3        V4        V5        V6  \
# 0      0.800452  0.045635 -0.727243  0.550011  0.123506  1.050435  2.322836
# 1      0.000821  0.153118 -0.000059 -0.088584 -0.080504 -0.367441 -0.002940
# 2      0.000821 -0.465822  0.602028 -0.171052  0.077048 -2.231288 -1.657247
# 3      0.000821 -1.674222  0.956607 -0.633900 -1.070936  1.565874  0.000008
# 4      0.000821 -2.645373 -0.000059  0.000106  0.547031  1.921488  1.985326
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995 -0.235682  1.777364  1.534321 -1.794881  3.781863  4.441433 -1.365955
# 49996  1.284981 -0.086359  0.042863 -1.874851 -0.000042 -0.608224  2.080941
# 49997 -0.701105  0.529425  0.976114 -2.886037 -0.000042  1.885142 -0.722091
# 49998  2.061601  0.778148 -0.000059 -0.056337  0.046687  0.302537  0.000008
# 49999  0.303707  0.000173  0.373847  0.744908 -0.835109  0.553668 -0.011494
#
#              V7
# 0     -0.891071
# 1      0.170517
# 2      1.869265
# 3      0.000002
# 4      0.178389
# ...         ...
# 49995  1.262033
# 49996  0.000002
# 49997 -0.642847
# 49998  0.495409
# 49999  0.377948
#
# [50000 rows x 8 columns]

# %%
Xtest_ohe_scaled.min()
# Out:
# V0   -2.114241
# V1   -4.237908
# V2   -6.554750
# V3   -5.414850
# V4   -5.351842
# V5   -6.177752
# V6   -5.463022
# V7   -5.323233
# dtype: float64

# %%
Xtest_ohe_scaled.max()
# Out:
# V0    2.738864
# V1    5.936593
# V2    7.300952
# V3    5.448391
# V4    5.472477
# V5    6.050044
# V6    5.539620
# V7    6.075459
# dtype: float64

# %% [markdown]
# ## [step4] 모델 설계
#  - 모델의 선택 및 학습, 예측, 평가 분석 모델 설계
#  - 다양한 모델의 성능비교 실시
#   - Logistic Regression, DecisioTree, Knn
#   - 트리기반 모델 중 배깅 기법을 적용한 Random Forest, ExtraTree,
#   - 트리기반 모델 중 부스팅 기법을 적용한 XGBoost와 Light GBM

# %% [markdown]
# - 성능을 평가하기 위해 학습 데이터셋에서 20%를 활용해 검증 데이터셋을 생성
#  - test_size = 0.2
#  - random_state = 10

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### (1) 훈련 및 검증 데이터 분할

# %%
# 데이터 분할: test_size=0.2, random_state=10

X_train, X_val, y_train, y_val = train_test_split(Xtrain_ohe_scaled, ytrain, test_size=0.2, random_state=10)

# %% [markdown]
# ### (2) 평가지표 확인
# - 평가지표가 accuracy이므로 skleran의 accuracy_score() 함수 사용

# %% [markdown]
# ### (3) 알고리즘별 학습, 예측, 평가 실시

# %% [markdown]
# #### 1) Logistic Regression

# %%
#객체생성
lr = LogisticRegression()   

#학습 
lr.fit(X_train, y_train)

#예측
lr_pred = lr.predict(X_val)

#평가 
print('Logistic Regression 모델의 정확도 : ', accuracy_score(y_val, lr_pred))
# Out:
# Logistic Regression 모델의 정확도 :  0.47164149244773435

# %% [markdown]
# #### 2) KNeighbors Classifier

# %%
#객체생성
knn = KNeighborsClassifier()

#학습 
knn.fit(X_train, y_train)

#예측
knn_pred = knn.predict(X_val)

#평가 
print('knn 모델의 정확도 (val) : ', accuracy_score(y_val, knn_pred))
# Out:
# knn 모델의 정확도 (val) :  0.5472641792537761

# %% [markdown]
# #### 3) Decision Tree Classifier

# %%
#객체생성
dt = DecisionTreeClassifier()

#학습 
dt.fit(X_train, y_train)

#예측
dt_pred = dt.predict(X_val)

#평가 
print('DT 모델의 정확도 (val) : ', accuracy_score(y_val, dt_pred))
# Out:
# DT 모델의 정확도 (val) :  0.4689406822046614

# %% [markdown]
# #### 4) Random Forest Classifier

# %%
#객체생성
rf = RandomForestClassifier()

#학습 
rf.fit(X_train, y_train)

#예측
rf_pred = rf.predict(X_val)

#평가
print('Random Forest 모델의 정확도(val) : ', accuracy_score(y_val, rf_pred))
# Out:
# Random Forest 모델의 정확도(val) :  0.6344903471041312

# %% [markdown]
# #### 5) Extra Tree Classifier

# %%
#객체생성
et = ExtraTreesClassifier()

#학습 
et.fit(X_train, y_train)

#예측
et_pred = et.predict(X_val)

#평가
print('Extra Tree 모델의 정확도(val) : ', accuracy_score(y_val, et_pred))### (2) Decision Tree Classifier
# Out:
# Extra Tree 모델의 정확도(val) :  0.6345903771131339

# %% [markdown]
# #### 56) XGBoost

# %%
#객체생성
xgb = XGBClassifier()

#학습 
xgb.fit(X_train, y_train)

#예측
xgb_pred = xgb.predict(X_val)

#평가
print('XGBoost 모델의 정확도(val) : ', accuracy_score(y_val, xgb_pred))
# Out:
# XGBoost 모델의 정확도(val) :  0.6360908272481745

# %% [markdown]
# #### 7) light GBM

# %%
#객체생성
#lgb = LGBMClassifier()
lgb = LGBMClassifier(verbose=-1)   #학습 및 예측시의 상세한 과정에 대한 메세지 및 warning 출력 생략

#학습 
lgb.fit(X_train, y_train)

#예측
lgb_pred = lgb.predict(X_val)

#평가
print('LGBM 모델의 정확도(val) : ', accuracy_score(y_val, lgb_pred))### (4) Extra Tree Classifier
# Out:
#   File "C:\Users\user\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 199, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\user\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# LGBM 모델의 정확도(val) :  0.6386916074822446

# %% [markdown]
# - 반복 작업을 for문으로 처리!

# %%
# 1) Logistic Regression ~ 7) LGBM Regressor

models = {    
    'LogisticRegression': LogisticRegression(),
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'Random Forest Classifier': RandomForestClassifier(n_jobs=-1),
    'Extra Trees Classifier': ExtraTreesClassifier(n_jobs=-1),
    'XGB Classifier' : XGBClassifier(verbose=-1,n_jobs=-1),
    'LGBM Classifier' : LGBMClassifier(verbose=-1,n_jobs=-1)
}

# %%
# 모델 학습 및 평가
for name, estimator in models.items():
    estimator.fit(X_train, y_train)
    pred = estimator.predict(X_val)
    score = accuracy_score(y_val, pred)
    print(f'[{name} 모델의 accuracy ]: {round(score, 4)}')
# Out:
# [LogisticRegression 모델의 accuracy ]: 0.4716
# [Decision Tree Classifier 모델의 accuracy ]: 0.4735
# [KNeighborsClassifier 모델의 accuracy ]: 0.5473
# [Random Forest Classifier 모델의 accuracy ]: 0.6315
# [Extra Trees Classifier 모델의 accuracy ]: 0.6312
# [XGB Classifier 모델의 accuracy ]: 0.6361
# [LGBM Classifier 모델의 accuracy ]: 0.6387

# %% [markdown]
# - 최적의 모델을 어떻게 기억해야 할까?

# %%
# 초기화: selected_estimator, max_score
selected_estimator = None
max_score = 0

# %%
# 모델 학습 및 평가
for name, estimator in models.items():
    estimator.fit(X_train, y_train)
    pred = estimator.predict(X_val)
    score = accuracy_score(y_val, pred)
    print(f'[{name} 모델의 accuracy ]: {round(score, 4)}')

    if score > max_score:
        selected_estimator = estimator
        max_score = score
        print('selected estimator: {}'.format(name))
    print('')
# Out:
# [LogisticRegression 모델의 accuracy ]: 0.4716
# selected estimator: LogisticRegression
#
# [Decision Tree Classifier 모델의 accuracy ]: 0.4749
# selected estimator: Decision Tree Classifier
#
# [KNeighborsClassifier 모델의 accuracy ]: 0.5473
# selected estimator: KNeighborsClassifier
#
# [Random Forest Classifier 모델의 accuracy ]: 0.633
# selected estimator: Random Forest Classifier
#
# [Extra Trees Classifier 모델의 accuracy ]: 0.6307
#
# [XGB Classifier 모델의 accuracy ]: 0.6361
# selected estimator: XGB Classifier
#
# [LGBM Classifier 모델의 accuracy ]: 0.6387
# selected estimator: LGBM Classifier

# %% [markdown]
# **[정리] 가장 정확도가 높은 모델을 사용하기로 결정**
# - https://xgboost.readthedocs.io/en/stable/parameter.html
# - https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html

# %%
selected_estimator
# Out:
# LGBMClassifier(n_jobs=-1, verbose=-1)

# %% [markdown]
# ### (4) 하이퍼 파라미터 튜닝
# - 검증 데이터셋을 이용한 평가에서 가장 좋은 성능을 보인 모델의 하이퍼 파라미터 튜닝
# - 3개의 파라미터 **(max_depth, learning_rate, n_estimators)** 튜닝

# %% [markdown]
# - 튜닝전에, default parameter일때의 성능을 Cross Validation 기반 재검증

# %%
from sklearn.model_selection import GridSearchCV

# 1) (Cross Validation이 목적이므로) 파라미터 설정은 하지 않음
parameters ={}

# 2) GridSearchCV 설정: 
grid_search = GridSearchCV(selected_estimator, 
                           parameters,
                           cv=5,
                           scoring='accuracy')

# 3) GridSearchCV estimator로 학습: 
grid_search.fit(Xtrain_ohe_scaled, ytrain)

# 4) Score확인
print('최적 하이퍼 파라미터 score: ', grid_search.best_score_)
# Out:
# 최적 하이퍼 파라미터 score:  0.6375712713814145

# %% [markdown]
# - 실제 하이퍼파라미터 튜닝 시작!

# %%
# 현재의 default 파라미터 확인
selected_estimator.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'verbose': -1}

# %% [raw]
# param_grid =
#     {'max_depth': [-1, 6, 10],                       #default 6 (0 indicates no limit on depth):XGB, -1:LGBM
#      'learning_rate':[0.1, 0.3, 0.5],              #default 03: XGB, 0.1: LGBM
#      'n_estimators': [50, 100, 200, 300]          #default 100
#     }
#
# cv=5

# %% [markdown]
# - 한꺼번에 진행하면,,,, (3 * 3 * 4 * 5)
#     - 너무 많은 조합으로 시간이 너무 오래 걸림. 따라서,
#     - 먼저 max_depth,  변화에 따른 성능 변화를 확인
#     - 이후 learning_rate, n_estimators 순으로 튜닝을 진행함

# %% [markdown]
# #### 1) 1차 GridSearchCV
# - 먼저 max_depth 변화에 따른 성능 변화를 확인
#     - 'max_depth': [-1, 6, 10]

# %%
param_grid ={
             'max_depth': [-1, 6, 10],
             'learning_rate' : [0.1],    # 일단 defualt 값으로 고정
             'n_estimators': [100]   # 일단 defualt 값으로 고정             
            }    

grid_search = GridSearchCV(selected_estimator, 
                           param_grid,
                           cv=5,
                           scoring='accuracy')                           
    
grid_search.fit(Xtrain_ohe_scaled, ytrain)

print('최적 하이퍼 파라미터 : ', grid_search.best_params_)
print('score : ', grid_search.best_score_)
# Out:
# 최적 하이퍼 파라미터 :  {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}
# score :  0.6375712713814145

# %% [markdown]
# - max_depth를 최적값으로 고정시켜 놓고 learning_rate, n_estimators 값을 탐색함

# %% [markdown]
# #### 2) 2차 GridSearchCV
# - learning_rate 변화에 따른 성능 변화를 확인
#     -  'learning_rate' : [0.1, 0.3, 0.5]

# %%
param_grid ={
             'max_depth': [-1],          # search한 최적 값으로 고정
             'learning_rate' : [0.1, 0.3, 0.5],        
             'n_estimators': [100]        # 일단 defualt 값으로 고정             
            } 

grid_search = GridSearchCV(selected_estimator, 
                           param_grid,
                           cv=5,
                           scoring='accuracy')                           
    
grid_search.fit(Xtrain_ohe_scaled, ytrain)

print('최적 하이퍼 파라미터 : ', grid_search.best_params_)
print('score : ', grid_search.best_score_)
# Out:
# 최적 하이퍼 파라미터 :  {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}
# score :  0.6375712713814145

# %% [markdown]
# #### 3) 3차 GridSearchCV
# - n_estimators 변화에 따른 성능 변화를 확인
#     -  'n_estimators': [50, 100, 200, 300]

# %%
param_grid ={
             'max_depth': [-1],          # search한 최적 값으로 고정
             'learning_rate' : [0.1],    # search한 최적 값으로 고정    
             'n_estimators': [50, 100, 200, 300] 
             }

grid_search = GridSearchCV(selected_estimator, 
                           param_grid,
                           cv=5,
                           scoring='accuracy')                           
    
grid_search.fit(Xtrain_ohe_scaled, ytrain)

print('최적 하이퍼 파라미터 : ', grid_search.best_params_)
print('score : ', grid_search.best_score_)
# Out:
# 최적 하이퍼 파라미터 :  {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 200}
# score :  0.6396518955686705

# %% [markdown]
# ## [step5] 모델 선택 및 적용
# ### (1) test data의 예측값 생성
# ![image.png](attachment:image.png)

# %%
#튜닝된 모델로 예측하기 
pred_test = grid_search.best_estimator_.predict(Xtest_ohe_scaled)

# %% [markdown]
# ### (2) 실제값과 예측값의 분포 비교

# %%
fig, axs = plt.subplots(1,2, figsize=(8,3))
sns.countplot(x=ytrain, ax=axs[0])
sns.countplot(x=pred_test, ax=axs[1])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## [step6] 결과 파일 생성
# ### (1) 예시 파일 불러오기

# %%
#예시 파일 불러오기
submission = pd.read_csv('./sample_submission.csv')
submission.head(5)
# Out:
#            ID  Class
# 0  TEST_00000      0
# 1  TEST_00001      0
# 2  TEST_00002      0
# 3  TEST_00003      0
# 4  TEST_00004      0

# %%
#test data의 예측 결과 저장하기
submission['Class'] = pred_test
submission.head(5)
# Out:
#            ID  Class
# 0  TEST_00000      1
# 1  TEST_00001      1
# 2  TEST_00002      4
# 3  TEST_00003      3
# 4  TEST_00004      0

# %%
#정답

#제출 파일 생성하기
submission.to_csv('./submission.csv', index=False)

# %% [markdown]
# **수고하셨습니다**
