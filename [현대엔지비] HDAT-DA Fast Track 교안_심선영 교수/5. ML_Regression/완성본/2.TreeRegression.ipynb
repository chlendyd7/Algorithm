# %% [markdown]
# # 회귀트리 실습 - 보스턴 주택 가격 예측

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 사이킷런 Estimator Class
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. 라이브러리 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 학습셋과 검증셋의 분리
from sklearn.model_selection import <blank>

# %% [markdown]
# ## 2. 데이터 셋 로드

# %% [raw]
# bostonDF=pd.read_csv('boston.csv')
# bostonDF

# %% [markdown]
# ## 3. Feature, Target 설정

# %%
#feature
X_features = bostonDF['RM']

# %%
#target
y_target= bostonDF['PRICE']
y_target

# %% [markdown]
# ## 4. 회귀트리(DecisionTreeRegressor)를 이용, 학습/예측

# %% [markdown]
# ### 4.1) 알고리즘 import

# %% [raw]
# from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### 4.2) 학습/예측 (max_depth=2)

# %% [raw]
# # 1. estimator생성
# dt_reg2 = DecisionTreeRegressor(max_depth=2)

# %% [raw]
# # 2. 학습셋과 검증셋의 분리
# X_train , X_val , y_train , y_val = train_test_split(X_features,
#                                                      y_target,
#                                                      test_size=0.3,
#                                                      random_state=156)

# %% [raw]
# # 3.학습
# dt_reg2.fit(X_train , y_train)

# %%
X_features

# %% [markdown]
# - 왜 에러가 났을까?
# - X_features를 어떻게 변경하여야 할까요?

# %% [markdown]
# - y_target은 1D-array여도 괜찮은데 왜 X_feaures는 2D-array여야 하는 것일까?
# - 일반적으로는 feature는 복수개로 가정-->2D-array
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor.predict

# %%
#2D가 되도록 하려면?

X_features = <blank>

# %%
# 2.학습셋과 검증셋의 분리
X_train , X_val , y_train , y_val = train_test_split(<blank>, <blank>, test_size=0.3, random_state=156)

# %%
# 3.학습
dt_reg2.<blank>(<blank> , <blank>)

# %%
# 4. 예측
pred_dt2 = dt_reg2.<blank>(<blank>)
pred_dt2 #예측값

# %%
<blank> #실제값

# %% [markdown]
# ### 4.3) 학습/예측 (max_depth=7)

# %%
# 1. estimator생성
dt_reg7 =<blank>(max_depth=7)

# %%
# 2. 학습 - 완성해 보세요.

# %%
# 3. 예측 - 완성해 보세요.
pred_dt7 =

# %%
y_val #실제값

# %% [markdown]
# ## 5. Linear Regression을 이용 학습/예측

# %% [markdown]
# ### 5.1) 알고리즘 import

# %%
from sklearn.linear_model import <blank>

# %% [markdown]
# ### 5.2) 학습/예측

# %%
# 1. estimator생성
lr_reg = <blank>

# %%
#2. 학습

# %%
#3. 예측
pred_lr =

# %%
y_val #실제값

# %% [markdown]
# ## 6. 결과 시각화

# %% [markdown]
# ### 6.1) 회귀트리(max_depth=2)로 학습된 모델의 회귀 예측선

# %%
plt.title('Decision Tree Regression: max_depth=2')
sns.scatterplot(x=X_val['RM'], y=y_val, c="darkorange")    #실제 데이터
sns.scatterplot(x=<blank>, y=pred_dt2, c="blue")       #예측 데이터
plt.show()

# %% [markdown]
# ### 6.2) 회귀트리(max_depth=7)로 학습된 모델의 회귀 예측선

# %%
#완성해 보세요!

# %% [markdown]
# ### 6.3)선형 회귀로 학습된 모델의 회귀 예측선

# %%
#완성해 보세요!

# %% [markdown]
# * **선형회귀는 직선으로 예측회귀선을 표현**
# * **회귀 트리는 분할되는 데이터 지점에 따라 브랜치를 만들면서 계단 형태로 회귀선 생성**
# * **max_depth=7의 경우, 이상치 데이터도 반복학습하여 복잡한 계단형 회귀선 생성, 과대적합 가능성**
